# %%
from Utilities import DrawPlots

# %%
dp = DrawPlots(json = 'https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json')
print(dp.draw_plots())
# Out:
# ['plots\\Comparing_ceiling_max_and_floor_max.jpg', 'plots\\Comparing_ceiling_mean_and_floor_mean.jpg', 'plots\\Comparing_ceiling_min_and_floor_min.jpg', 'plots\\Comparing_max_and_ceiling_max.jpg', 'plots\\Comparing_max_and_floor_max.jpg', 'plots\\Comparing_mean_and_ceiling_mean.jpg', 'plots\\Comparing_mean_and_floor_mean.jpg', 'plots\\Comparing_min_and_ceiling_min.jpg', 'plots\\Comparing_min_and_floor_min.jpg', 'plots\\Confusion_matrix.jpg', 'plots\\Correlation_between_columns.jpg']
